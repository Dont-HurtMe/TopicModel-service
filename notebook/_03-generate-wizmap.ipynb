# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import random
import pickle
import os

# %% [markdown]
# # **Generate Wizmap**

# %%
from model.generate_wizmap import Generate_Wizmap

# %%
data = pd.read_parquet('./output_test/data.parquet')

# %%
data
# Out:
#                                            data_process  \
# 0     title: Quantitative HPLC Determination and Sta...
# 1     title: Insecticidal activity of Stemona collin...
# 2     title: Oral toxicity of various Stemona collin...
# 3     title: Optimized extraction for high yield of ...
# 4     title: Acetylcholinesterase inhibitory activit...
# ...                                                 ...
# 1951  title: Effects of Onion (Allium cepa L.) and G...
# 1952  title: Methods of Isolation of Active Substanc...
# 1953  title: Garlic (Allium sativum L.): a potential...
# 1954  title: Character association and path analysis...
# 1955  title: Antibacterial effect of different conce...
#
#                                                  vector         x         y  \
# 0     [-0.0074133547, -0.017918514, -0.08736931, -0.... -2.303174  8.624246
# 1     [0.0048623416, -0.044462435, -0.1135353, -0.04... -2.333353  9.045902
# ...

# %%
with open(os.path.join('./output_test/model_log.pkl'), 'rb') as f:
    loaded_object = pickle.load(f)

# %%
cv = loaded_object.get('cv')
cv
# Out:
# CountVectorizer(stop_words='english')

# %%
generator = Generate_Wizmap(save_file_path='./output_test', cv=cv, verbose=True)

# %%
generator.input(data)

# %%
generator.run()
# Out:
# /Users/peetiphartsuebpeng/Documents/11-PROJECT-WizMap/generate-wizmap-dev/model/generate_wizmap/node.py:264: UserWarning: You passed a edgecolor/edgecolors ('k') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(centers[:, 0], centers[:, 1], marker='x', c='red', s=50, edgecolors='k')
# 1956it [00:00, 408527.97it/s]
# ...
# 100%|██████████████████████████| 1956/1956 [00:00<00:00, 3697187.30it/s]

# %%
from model.generate_wizmap import wizmap_local

# %%
wizmap_local(directory_folder_of_wizmap='./output_test/wizmapJson/', port=1234)
# Out:
# https://poloclub.github.io/wizmap/?dataURL=http://localhost:1234/./output_test/wizmapJson/data.ndjson&gridURL=http://localhost:1234/./output_test/wizmapJson/grid.json
