# %% [markdown]
# # **For DEV**

# %%
import pandas as pd
import re
import string
import pandas as pd

def cleanText(text):
    
    # source : https://github.com/naenumtou
    clear_list = r'(?:http|ftp|https)://(?:[\w_-]+(?:(?:\.[\w_-]+)+))(?:[\w.,@?^=%&:/~+#]*[\w@?^=%&/~+#])?|“|”|[()\/\+\*.,]|,|ๆ|<.*?>|#|'
    
    # text = re.sub(r'\d+', '', text)  # Remove digits
    text = re.sub(clear_list,'',text)

    # ลบ เครื่องหมายคำพูด (punctuation)
    for c in string.punctuation:
       text = re.sub(r'\{}'.format(c),'',text)
        
    text = ' '.join(text.split())
    # text = text.translate(str.maketrans('', '', textPunc)) # Remove punctuation without (.)
    text = ' '.join(text.split())  # Keep only one white space
    return text

df = pd.read_parquet('../../08-HERB/input/herb_researchgate_10keyword.parquet')
df = df[~df['abstract'].isna()]
# df['text'] = df['text'].apply(cleanText)
df['text'] = 'title: ' + df['title'] + ' pub_year: ' + df['pub_year'] + ' keyword: ' + df['keyword'] + ' abstract: ' + df['abstract']
df
# Out:
#                         id                                              title  \
# 0     Stemona_collinsiae_1  Quantitative HPLC Determination and Stability ...
# 1     Stemona_collinsiae_2  Insecticidal activity of Stemona collinsiae ro...
# 2     Stemona_collinsiae_3  Oral toxicity of various Stemona collinsiae cr...
# 3     Stemona_collinsiae_4  Optimized extraction for high yield of insecti...
# 4     Stemona_collinsiae_5  Acetylcholinesterase inhibitory activity of di...
# ...                    ...                                                ...
# 2138    Allium_sativum_237  Effects of Onion (Allium cepa L.) and Garlic (...
# 2139    Allium_sativum_238  Methods of Isolation of Active Substances from...
# 2142    Allium_sativum_241  Garlic (Allium sativum L.): a potential unique...
# 2143    Allium_sativum_242  Character association and path analysis in gar...
# 2144    Allium_sativum_243  Antibacterial effect of different concentratio...
#
#                                                abstract pub_year  \
# 0     A reversed-phase high-performance liquid chrom...     2008
# 1     In Thai indigenous knowledge, Stemona plant ha...     2017
# 2     Stemona collinsiae exhibits insecticidal resis...     2021
# 3     Stemona plants, which are popularly called “No...     2013
# 4     Introduction: Acetylcholinesterase (AChE) inhi...     2013
# ...                                                 ...      ...
# 2138  In the present study the effects of individual...     2012
# 2139  Garlic (Allium sativum L.) is widely used in t...     2022
# 2142  Coronavirus disease 2019 (COVID-19) is the cur...     2020
# 2143  Character association and path analysis in twe...     2014
# 2144  Background: Allium sativum, commonly known as ...     2013
#
#                                            authors_list             keyword  \
# 0     [Ruedeekorn Wiwattanapatapee, Chitchamai Ovatl...  Stemona_collinsiae
# 1     [Siriluck Attrapadung, Aurapa Sakulpanich, Wan...  Stemona_collinsiae
# 2     [Nontapat Sarovath, Preeyanate Dathong, Napaso...  Stemona_collinsiae
# 3     [Sumet Kongkiatpaiboon, Phyto Product Research...  Stemona_collinsiae
# 4     [Pattarajinda Virote, Khon Kaen University, Wa...  Stemona_collinsiae
# ...                                                 ...                 ...
# 2138  [Sunčica Kocić-Tanackov, University of Novi Sa...      Allium_sativum
# 2139  [Monika Bar, Urszula E. Binduga, Wyższa Szkoła...      Allium_sativum
# 2142  [Sucheta Khubber, Seyed Mohammad Taghi Gharibz...      Allium_sativum
# 2143  [Shiv Lal, NA Ahmed, S. R Singh, National Rese...      Allium_sativum
# 2144  [Behzad Houshmand, Shahid Beheshti University ...      Allium_sativum
#
#                    relative_date  \
# 0     2024-06-01T14:27:30.335303
# 1     2024-06-01T14:27:54.172213
# 2     2024-06-01T14:28:11.782212
# 3     2024-06-01T14:28:29.777971
# 4     2024-06-01T14:28:51.335262
# ...                          ...
# 2138  2024-06-03T20:50:46.716683
# 2139  2024-06-03T20:51:06.279667
# 2142  2024-06-03T20:53:44.404606
# 2143  2024-06-03T20:53:56.664256
# 2144  2024-06-03T20:54:09.488265
#
#                                                    link  \
# 0     https://www.researchgate.net/publication/22577...
# 1     https://www.researchgate.net/publication/31713...
# 2     https://www.researchgate.net/publication/35456...
# 3     https://www.researchgate.net/publication/23615...
# 4     https://www.researchgate.net/publication/24503...
# ...                                                 ...
# 2138  https://www.researchgate.net/publication/22400...
# 2139  https://www.researchgate.net/publication/36187...
# 2142  https://www.researchgate.net/publication/34705...
# 2143  https://www.researchgate.net/publication/26982...
# 2144  https://www.researchgate.net/publication/24932...
#
#                                                    text
# 0     title: Quantitative HPLC Determination and Sta...
# 1     title: Insecticidal activity of Stemona collin...
# 2     title: Oral toxicity of various Stemona collin...
# 3     title: Optimized extraction for high yield of ...
# 4     title: Acetylcholinesterase inhibitory activit...
# ...                                                 ...
# 2138  title: Effects of Onion (Allium cepa L.) and G...
# 2139  title: Methods of Isolation of Active Substanc...
# 2142  title: Garlic (Allium sativum L.): a potential...
# 2143  title: Character association and path analysis...
# 2144  title: Antibacterial effect of different conce...
#
# [1956 rows x 9 columns]

# %%
df = df.sample(200)

# %% [markdown]
# ## Generate_Vector

# %%
from model.generate_vector import Generate_Vector
from sentence_transformers import SentenceTransformer 
from umap import UMAP

# %%
verbose = True
transformer = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2',device='cpu')
reducer = UMAP(verbose=verbose)
generator = Generate_Vector(embedding_model=transformer, 
    reduce_dimension_model=reducer ,
    batch_size=120, 
    verbose=verbose, 
    save_path='./output/')
# Out:
# /Users/peetiphartsuebpeng/Documents/CONDA_ENV/env-wizmap/lib/python3.12/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
generator.input(df['text'].tolist())

# %%
model_log, data = generator.run()
# Out:
# ###### Words Embedding ######
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# ###### Vector Reduction Dimensions ######
#
# UMAP( verbose=True)
# Thu Jun 20 14:49:10 2024 Construct fuzzy simplicial set
# Thu Jun 20 14:49:10 2024 Finding Nearest Neighbors
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# Thu Jun 20 14:49:11 2024 Finished Nearest Neighbor Search
# Thu Jun 20 14:49:12 2024 Construct embedding
# Epochs completed:   0%|            0/500 [00:00]
# 	completed  0  /  500 epochs
# 	completed  50  /  500 epochs
# 	completed  100  /  500 epochs
# 	completed  150  /  500 epochs
# 	completed  200  /  500 epochs
# 	completed  250  /  500 epochs
# 	completed  300  /  500 epochs
# 	completed  350  /  500 epochs
# 	completed  400  /  500 epochs
# 	completed  450  /  500 epochs
# Thu Jun 20 14:49:13 2024 Finished embedding

# %%
data
# Out:
#                                           data_process  \
# 0    title: Genotype by environment interaction eff...
# 1    title: Bioassay-guided isolation of a vasorela...
# 2    title: Bioadhesive dermal patch as promising a...
# 3    title: ESSENTIAL OIL OF Curcuma longa L. RHIZO...
# 4    title: Adaptogenic-active components from Kaem...
# ..                                                 ...
# 195  title: Challenges in Optimizing Nanoplatforms ...
# 196  title: The Role of Garlic in Hepatopulmonary S...
# 197  title: Identifikasi Jenis Bahan Aktif dan Peng...
# 198  title: Dry-matter production and accumulation ...
# 199  title: Haematological and Hepatotoxic Potentia...
#
#                                                 vector         x         y  \
# 0    [-0.011761735, -0.024193902, -0.06229731, 0.03... -3.358461  2.305671
# 1    [-0.014491484, -0.01157876, -0.09853511, -0.01... -5.938834  4.781258
# 2    [-0.05881872, -0.04401235, -0.041604377, -0.03... -4.507442  3.216583
# 3    [0.0023844952, -0.061585624, -0.06964083, 0.01... -3.562569  2.119775
# 4    [0.0131213525, -0.05999834, -0.053973444, 0.05... -6.321672  6.169890
# ..                                                 ...       ...       ...
# 195  [0.032540128, -0.1696602, 0.026023295, -0.0140... -4.136169  3.087486
# 196  [0.015100233, 0.036982786, -0.08282912, 0.0598... -1.441832  7.270166
# 197  [-0.00013802102, -0.002648368, -0.034641653, -... -4.780901  5.052386
# 198  [0.034621872, -0.015346619, -0.06576741, 0.010... -6.423589  4.243403
# 199  [0.06593641, -0.0048804423, -0.050979175, 0.03... -1.572780  7.747817
#
#                                           data_display
# 0    X: -3.3585 Y: 2.3057 Content: title: Genotype ...
# 1    X: -5.9388 Y: 4.7813 Content: title: Bioassay-...
# 2    X: -4.5074 Y: 3.2166 Content: title: Bioadhesi...
# 3    X: -3.5626 Y: 2.1198 Content: title: ESSENTIAL...
# 4    X: -6.3217 Y: 6.1699 Content: title: Adaptogen...
# ..                                                 ...
# 195  X: -4.1362 Y: 3.0875 Content: title: Challenge...
# 196  X: -1.4418 Y: 7.2702 Content: title: The Role ...
# 197  X: -4.7809 Y: 5.0524 Content: title: Identifik...
# 198  X: -6.4236 Y: 4.2434 Content: title: Dry-matte...
# 199  X: -1.5728 Y: 7.7478 Content: title: Haematolo...
#
# [200 rows x 5 columns]

# %%
model_log
# Out:
# {'sentence_transform': {'model': SentenceTransformer(
#     (0): Transformer({'max_seq_length': 256, 'do_lower_case': False}) with Transformer model: BertModel
#     (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#     (2): Normalize()
#   ),
#   'vector': array([[-0.01176174, -0.0241939 , -0.06229731, ..., -0.00565795,
#           -0.02784921, -0.03368229],
#          [-0.01449148, -0.01157876, -0.09853511, ..., -0.0435152 ,
#            0.0094782 ,  0.03067777],
#          [-0.05881872, -0.04401235, -0.04160438, ..., -0.0961917 ,
#            0.04917942,  0.08210851],
#          ...,
#          [-0.00013802, -0.00264837, -0.03464165, ..., -0.08349542,
#           -0.02912513,  0.04641533],
#          [ 0.03462187, -0.01534662, -0.06576741, ..., -0.07276306,
#           -0.03242632, -0.0106422 ],
#          [ 0.06593641, -0.00488044, -0.05097917, ...,  0.0432571 ,
#           -0.01390328,  0.05606864]], dtype=float32)},
#  'umap': UMAP( verbose=True)}

# %% [markdown]
# ## Mini_Bert

# %%
from model.generate_topic import llm_summary_cluster, find_topic, Mini_Bert
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import CountVectorizer

# %%
df = pd.read_parquet('./output/data.parquet')
df
# Out:
#                                           data_process  \
# 0    title: Genotype by environment interaction eff...
# 1    title: Bioassay-guided isolation of a vasorela...
# 2    title: Bioadhesive dermal patch as promising a...
# 3    title: ESSENTIAL OIL OF Curcuma longa L. RHIZO...
# 4    title: Adaptogenic-active components from Kaem...
# ..                                                 ...
# 195  title: Challenges in Optimizing Nanoplatforms ...
# 196  title: The Role of Garlic in Hepatopulmonary S...
# 197  title: Identifikasi Jenis Bahan Aktif dan Peng...
# 198  title: Dry-matter production and accumulation ...
# 199  title: Haematological and Hepatotoxic Potentia...
#
#                                                 vector         x         y  \
# 0    [-0.011761735, -0.024193902, -0.06229731, 0.03... -3.358461  2.305671
# 1    [-0.014491484, -0.01157876, -0.09853511, -0.01... -5.938834  4.781258
# 2    [-0.05881872, -0.04401235, -0.041604377, -0.03... -4.507442  3.216583
# 3    [0.0023844952, -0.061585624, -0.06964083, 0.01... -3.562569  2.119775
# 4    [0.0131213525, -0.05999834, -0.053973444, 0.05... -6.321672  6.169890
# ..                                                 ...       ...       ...
# 195  [0.032540128, -0.1696602, 0.026023295, -0.0140... -4.136169  3.087486
# 196  [0.015100233, 0.036982786, -0.08282912, 0.0598... -1.441832  7.270166
# 197  [-0.00013802102, -0.002648368, -0.034641653, -... -4.780901  5.052386
# 198  [0.034621872, -0.015346619, -0.06576741, 0.010... -6.423589  4.243403
# 199  [0.06593641, -0.0048804423, -0.050979175, 0.03... -1.572780  7.747817
#
#                                           data_display
# 0    X: -3.3585 Y: 2.3057 Content: title: Genotype ...
# 1    X: -5.9388 Y: 4.7813 Content: title: Bioassay-...
# 2    X: -4.5074 Y: 3.2166 Content: title: Bioadhesi...
# 3    X: -3.5626 Y: 2.1198 Content: title: ESSENTIAL...
# 4    X: -6.3217 Y: 6.1699 Content: title: Adaptogen...
# ..                                                 ...
# 195  X: -4.1362 Y: 3.0875 Content: title: Challenge...
# 196  X: -1.4418 Y: 7.2702 Content: title: The Role ...
# 197  X: -4.7809 Y: 5.0524 Content: title: Identifik...
# 198  X: -6.4236 Y: 4.2434 Content: title: Dry-matte...
# 199  X: -1.5728 Y: 7.7478 Content: title: Haematolo...
#
# [200 rows x 5 columns]

# %%
kmeans = KMeans(n_clusters=3, random_state=123, n_init="auto", )
cvec = CountVectorizer(stop_words="english", ngram_range=(1, 1))

# %%
bert = Mini_Bert(gemini_token=gemini_key,
                 save_path="./output", 
                 cluster=kmeans, 
                 cv=cvec, 
                 verbose=True)

# %%
bert.input(df)
rs, model_log, df = bert.run()
# rs = bert.run()
# Out:
# Cluster :   0%|          | 0/3 [00:00<?, ?it/s]
# /Users/peetiphartsuebpeng/Documents/PROJECT/generate-wizmap-dev/model/generate_topic/node.py:240: UserWarning: create summary fail	e:429 Resource has been exhausted (e.g. check quota). attemp new one
#   warnings.warn(f"create summary fail\te:{e} attemp new one")

# %%
# eval(err[0].replace('// Add more details as needed', ''))

# %%
df
# Out:
#                                           data_process  \
# 0    title: Genotype by environment interaction eff...
# 1    title: Bioassay-guided isolation of a vasorela...
# 2    title: Bioadhesive dermal patch as promising a...
# 3    title: ESSENTIAL OIL OF Curcuma longa L. RHIZO...
# 4    title: Adaptogenic-active components from Kaem...
# ..                                                 ...
# 195  title: Challenges in Optimizing Nanoplatforms ...
# 196  title: The Role of Garlic in Hepatopulmonary S...
# 197  title: Identifikasi Jenis Bahan Aktif dan Peng...
# 198  title: Dry-matter production and accumulation ...
# 199  title: Haematological and Hepatotoxic Potentia...
#
#                                                 vector         x         y  \
# 0    [-0.011761735, -0.024193902, -0.06229731, 0.03... -3.358461  2.305671
# 1    [-0.014491484, -0.01157876, -0.09853511, -0.01... -5.938834  4.781258
# 2    [-0.05881872, -0.04401235, -0.041604377, -0.03... -4.507442  3.216583
# 3    [0.0023844952, -0.061585624, -0.06964083, 0.01... -3.562569  2.119775
# 4    [0.0131213525, -0.05999834, -0.053973444, 0.05... -6.321672  6.169890
# ..                                                 ...       ...       ...
# 195  [0.032540128, -0.1696602, 0.026023295, -0.0140... -4.136169  3.087486
# 196  [0.015100233, 0.036982786, -0.08282912, 0.0598... -1.441832  7.270166
# 197  [-0.00013802102, -0.002648368, -0.034641653, -... -4.780901  5.052386
# 198  [0.034621872, -0.015346619, -0.06576741, 0.010... -6.423589  4.243403
# 199  [0.06593641, -0.0048804423, -0.050979175, 0.03... -1.572780  7.747817
#
#                                           data_display  cluster
# 0    X: -3.3585 Y: 2.3057 Content: title: Genotype ...        1
# 1    X: -5.9388 Y: 4.7813 Content: title: Bioassay-...        0
# 2    X: -4.5074 Y: 3.2166 Content: title: Bioadhesi...        1
# 3    X: -3.5626 Y: 2.1198 Content: title: ESSENTIAL...        1
# 4    X: -6.3217 Y: 6.1699 Content: title: Adaptogen...        0
# ..                                                 ...      ...
# 195  X: -4.1362 Y: 3.0875 Content: title: Challenge...        1
# 196  X: -1.4418 Y: 7.2702 Content: title: The Role ...        2
# 197  X: -4.7809 Y: 5.0524 Content: title: Identifik...        0
# 198  X: -6.4236 Y: 4.2434 Content: title: Dry-matte...        1
# 199  X: -1.5728 Y: 7.7478 Content: title: Haematolo...        2
#
# [200 rows x 6 columns]

# %% [markdown]
# ## Generate_Wizmap

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from model.generate_wizmap import Generate_Wizmap

# %%
df = pd.read_parquet('./output/data.parquet')
df
# Out:
#                                           data_process  \
# 0    title: Genotype by environment interaction eff...
# 1    title: Bioassay-guided isolation of a vasorela...
# 2    title: Bioadhesive dermal patch as promising a...
# 3    title: ESSENTIAL OIL OF Curcuma longa L. RHIZO...
# 4    title: Adaptogenic-active components from Kaem...
# ..                                                 ...
# 195  title: Challenges in Optimizing Nanoplatforms ...
# 196  title: The Role of Garlic in Hepatopulmonary S...
# 197  title: Identifikasi Jenis Bahan Aktif dan Peng...
# 198  title: Dry-matter production and accumulation ...
# 199  title: Haematological and Hepatotoxic Potentia...
#
#                                                 vector         x         y  \
# 0    [-0.011761735, -0.024193902, -0.06229731, 0.03... -3.358461  2.305671
# 1    [-0.014491484, -0.01157876, -0.09853511, -0.01... -5.938834  4.781258
# 2    [-0.05881872, -0.04401235, -0.041604377, -0.03... -4.507442  3.216583
# 3    [0.0023844952, -0.061585624, -0.06964083, 0.01... -3.562569  2.119775
# 4    [0.0131213525, -0.05999834, -0.053973444, 0.05... -6.321672  6.169890
# ..                                                 ...       ...       ...
# 195  [0.032540128, -0.1696602, 0.026023295, -0.0140... -4.136169  3.087486
# 196  [0.015100233, 0.036982786, -0.08282912, 0.0598... -1.441832  7.270166
# 197  [-0.00013802102, -0.002648368, -0.034641653, -... -4.780901  5.052386
# 198  [0.034621872, -0.015346619, -0.06576741, 0.010... -6.423589  4.243403
# 199  [0.06593641, -0.0048804423, -0.050979175, 0.03... -1.572780  7.747817
#
#                                           data_display  cluster
# 0    X: -3.3585 Y: 2.3057 Content: title: Genotype ...        1
# 1    X: -5.9388 Y: 4.7813 Content: title: Bioassay-...        0
# 2    X: -4.5074 Y: 3.2166 Content: title: Bioadhesi...        1
# 3    X: -3.5626 Y: 2.1198 Content: title: ESSENTIAL...        1
# 4    X: -6.3217 Y: 6.1699 Content: title: Adaptogen...        0
# ..                                                 ...      ...
# 195  X: -4.1362 Y: 3.0875 Content: title: Challenge...        1
# 196  X: -1.4418 Y: 7.2702 Content: title: The Role ...        2
# 197  X: -4.7809 Y: 5.0524 Content: title: Identifik...        0
# 198  X: -6.4236 Y: 4.2434 Content: title: Dry-matte...        1
# 199  X: -1.5728 Y: 7.7478 Content: title: Haematolo...        2
#
# [200 rows x 6 columns]

# %%
cvec = CountVectorizer(stop_words="english", ngram_range=(1, 1))
wizGenerator = Generate_Wizmap(save_file_path='./output/', cv=cvec, verbose=True, path_model_log='./output/')

# %%
wizGenerator.input(df)

# %%
wizGenerator.run()
# Out:
# ###   compute grid...  ###
# coordinate:  -8.625001628398895 0.8192280936241154 -0.9898766684532165 8.454353053569793
# 200it [00:00, 486860.59it/s]
# 5 9
# 100%|███████████████████████████████████| 5/5 [00:00<00:00, 54.96it/s]
# ###   compute data...  ###
# 100%|██████████████████████████| 200/200 [00:00<00:00, 3238844.79it/s]
# ###   save data...  ###

# %%
from model.generate_wizmap import wizmap_local

# %%
wizmap_local(directory_folder_of_wizmap='./output/wizmapJson/',port=3333)
# Out:
# https://poloclub.github.io/wizmap/?dataURL=http://localhost:3333/./output/wizmapJson/data.ndjson&gridURL=http://localhost:3333/./output/wizmapJson/grid.json
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 127.0.0.1 - - [20/Jun/2024 14:55:29] "OPTIONS /output/wizmapJson/grid.json HTTP/1.1" 204 -
# 127.0.0.1 - - [20/Jun/2024 14:55:29] "GET /output/wizmapJson/grid.json HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Jun/2024 14:55:29] "OPTIONS /output/wizmapJson/data.ndjson HTTP/1.1" 204 -
# 127.0.0.1 - - [20/Jun/2024 14:55:29] "GET /output/wizmapJson/data.ndjson HTTP/1.1" 200 -
# <class 'http_server.server.CORSRequestHandler'>
# Starting httpd server on port 3333...
# Traceback (most recent call last):
#   File "/Users/peetiphartsuebpeng/Documents/CONDA_ENV/env-wizmap/bin/server", line 8, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/Users/peetiphartsuebpeng/Documents/CONDA_ENV/env-wizmap/lib/python3.12/site-packages/http_server/server.py", line 31, in main
#     run(port=args.port, allow_all_cors=args.allow_cors)
#   File "/Users/peetiphartsuebpeng/Documents/CONDA_ENV/env-wizmap/lib/python3.12/site-packages/http_server/server.py", line 22, in run
#     httpd.serve_forever()
#   File "/Users/peetiphartsuebpeng/Documents/CONDA_ENV/env-wizmap/lib/python3.12/socketserver.py", line 235, in serve_forever
#     ready = selector.select(poll_interval)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/peetiphartsuebpeng/Documents/CONDA_ENV/env-wizmap/lib/python3.12/selectors.py", line 415, in select
#     fd_event_list = self._selector.poll(timeout)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 wizmap_local(directory_folder_of_wizmap='./output/wizmapJson/',port=3333)
#
# File ~/Documents/PROJECT/generate-wizmap-dev/model/generate_wizmap/node.py:595, in wizmap_local(directory_folder_of_wizmap, port)
#     591 wiz_url = f"https://poloclub.github.io/wizmap/?dataURL={url+data}&gridURL={url+grid}"
#     593 print(wiz_url)
# --> 595 subprocess.run(["server", f"--port={port}", "--allow_cors"], check=True)
#
# File ~/Documents/CONDA_ENV/env-wizmap/lib/python3.12/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File ~/Documents/CONDA_ENV/env-wizmap/lib/python3.12/subprocess.py:1201, in Popen.communicate(self, input, timeout)
#    1199         stderr = self.stderr.read()
#    1200         self.stderr.close()
# -> 1201     self.wait()
#    1202 else:
#    1203     if timeout is not None:
#
# File ~/Documents/CONDA_ENV/env-wizmap/lib/python3.12/subprocess.py:1264, in Popen.wait(self, timeout)
#    1262     endtime = _time() + timeout
#    1263 try:
# -> 1264     return self._wait(timeout=timeout)
#    1265 except KeyboardInterrupt:
#    1266     # https://bugs.python.org/issue25942
#    1267     # The first keyboard interrupt waits briefly for the child to
#    1268     # exit under the common assumption that it also received the ^C
#    1269     # generated SIGINT and will exit rapidly.
#    1270     if timeout is not None:
#
# File ~/Documents/CONDA_ENV/env-wizmap/lib/python3.12/subprocess.py:2046, in Popen._wait(self, timeout)
#    2044 if self.returncode is not None:
#    2045     break  # Another thread waited.
# -> 2046 (pid, sts) = self._try_wait(0)
#    2047 # Check the pid and loop as waitpid has been known to
#    2048 # return 0 even without WNOHANG in odd situations.
#    2049 # http://bugs.python.org/issue14396.
#    2050 if pid == self.pid:
#
# File ~/Documents/CONDA_ENV/env-wizmap/lib/python3.12/subprocess.py:2004, in Popen._try_wait(self, wait_flags)
#    2002 """All callers to this function MUST hold self._waitpid_lock."""
#    2003 try:
# -> 2004     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    2005 except ChildProcessError:
#    2006     # This happens if SIGCLD is set to be ignored or waiting
#    2007     # for child processes has otherwise been disabled for our
#    2008     # process.  This child is dead, we can't get the status.
#    2009     pid = self.pid
#
# KeyboardInterrupt:

# %% [markdown]
# # **One-Short**

# %%
from model import TopicModel, local_graph
from sklearn.cluster import MeanShift
from sentence_transformers import SentenceTransformer 
from umap import UMAP
from sklearn.feature_extraction.text import CountVectorizer
from pythainlp.tokenize import word_tokenize
from pythainlp.corpus.common import thai_stopwords
from datasets import load_dataset
import pandas as pd
import re
import string

def cleanText(text):
    
    # source : https://github.com/naenumtou
    clear_list = r'(?:http|ftp|https)://(?:[\w_-]+(?:(?:\.[\w_-]+)+))(?:[\w.,@?^=%&:/~+#]*[\w@?^=%&/~+#])?|“|”|[()\/\+\*.,]|,|ๆ|<.*?>|#|'
    
    # text = re.sub(r'\d+', '', text)  # Remove digits
    text = re.sub(clear_list,'',text)

    # ลบ เครื่องหมายคำพูด (punctuation)
    for c in string.punctuation:
       text = re.sub(r'\{}'.format(c),'',text)
        
    text = ' '.join(text.split())
    # text = text.translate(str.maketrans('', '', textPunc)) # Remove punctuation without (.)
    text = ' '.join(text.split())  # Keep only one white space
    return text

df = pd.read_parquet('../../08-HERB/input/herb_researchgate_10keyword.parquet')
df = df[~df['abstract'].isna()]
# df['text'] = df['text'].apply(cleanText)
df['text'] = 'title: ' + df['title'] + ' pub_year: ' + df['pub_year'] + ' keyword: ' + df['keyword'] + ' abstract: ' + df['abstract']
df
# Out:
# /Users/peetiphartsuebpeng/Documents/11-PROJECT-WizMap/embedding-service/model/generate_vector/node.py:6: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
#                         id                                              title  \
# 0     Stemona_collinsiae_1  Quantitative HPLC Determination and Stability ...
# 1     Stemona_collinsiae_2  Insecticidal activity of Stemona collinsiae ro...
# 2     Stemona_collinsiae_3  Oral toxicity of various Stemona collinsiae cr...
# 3     Stemona_collinsiae_4  Optimized extraction for high yield of insecti...
# 4     Stemona_collinsiae_5  Acetylcholinesterase inhibitory activity of di...
# ...                    ...                                                ...
# 2138    Allium_sativum_237  Effects of Onion (Allium cepa L.) and Garlic (...
# 2139    Allium_sativum_238  Methods of Isolation of Active Substances from...
# 2142    Allium_sativum_241  Garlic (Allium sativum L.): a potential unique...
# 2143    Allium_sativum_242  Character association and path analysis in gar...
# 2144    Allium_sativum_243  Antibacterial effect of different concentratio...
#
#                                                abstract pub_year  \
# 0     A reversed-phase high-performance liquid chrom...     2008
# 1     In Thai indigenous knowledge, Stemona plant ha...     2017
# 2     Stemona collinsiae exhibits insecticidal resis...     2021
# 3     Stemona plants, which are popularly called “No...     2013
# 4     Introduction: Acetylcholinesterase (AChE) inhi...     2013
# ...                                                 ...      ...
# 2138  In the present study the effects of individual...     2012
# 2139  Garlic (Allium sativum L.) is widely used in t...     2022
# 2142  Coronavirus disease 2019 (COVID-19) is the cur...     2020
# 2143  Character association and path analysis in twe...     2014
# 2144  Background: Allium sativum, commonly known as ...     2013
#
#                                            authors_list             keyword  \
# 0     [Ruedeekorn Wiwattanapatapee, Chitchamai Ovatl...  Stemona_collinsiae
# 1     [Siriluck Attrapadung, Aurapa Sakulpanich, Wan...  Stemona_collinsiae
# 2     [Nontapat Sarovath, Preeyanate Dathong, Napaso...  Stemona_collinsiae
# 3     [Sumet Kongkiatpaiboon, Phyto Product Research...  Stemona_collinsiae
# 4     [Pattarajinda Virote, Khon Kaen University, Wa...  Stemona_collinsiae
# ...                                                 ...                 ...
# 2138  [Sunčica Kocić-Tanackov, University of Novi Sa...      Allium_sativum
# 2139  [Monika Bar, Urszula E. Binduga, Wyższa Szkoła...      Allium_sativum
# 2142  [Sucheta Khubber, Seyed Mohammad Taghi Gharibz...      Allium_sativum
# 2143  [Shiv Lal, NA Ahmed, S. R Singh, National Rese...      Allium_sativum
# 2144  [Behzad Houshmand, Shahid Beheshti University ...      Allium_sativum
#
#                    relative_date  \
# 0     2024-06-01T14:27:30.335303
# 1     2024-06-01T14:27:54.172213
# 2     2024-06-01T14:28:11.782212
# 3     2024-06-01T14:28:29.777971
# 4     2024-06-01T14:28:51.335262
# ...                          ...
# 2138  2024-06-03T20:50:46.716683
# 2139  2024-06-03T20:51:06.279667
# 2142  2024-06-03T20:53:44.404606
# 2143  2024-06-03T20:53:56.664256
# 2144  2024-06-03T20:54:09.488265
#
#                                                    link  \
# 0     https://www.researchgate.net/publication/22577...
# 1     https://www.researchgate.net/publication/31713...
# 2     https://www.researchgate.net/publication/35456...
# 3     https://www.researchgate.net/publication/23615...
# 4     https://www.researchgate.net/publication/24503...
# ...                                                 ...
# 2138  https://www.researchgate.net/publication/22400...
# 2139  https://www.researchgate.net/publication/36187...
# 2142  https://www.researchgate.net/publication/34705...
# 2143  https://www.researchgate.net/publication/26982...
# 2144  https://www.researchgate.net/publication/24932...
#
#                                                    text
# 0     title: Quantitative HPLC Determination and Sta...
# 1     title: Insecticidal activity of Stemona collin...
# 2     title: Oral toxicity of various Stemona collin...
# 3     title: Optimized extraction for high yield of ...
# 4     title: Acetylcholinesterase inhibitory activit...
# ...                                                 ...
# 2138  title: Effects of Onion (Allium cepa L.) and G...
# 2139  title: Methods of Isolation of Active Substanc...
# 2142  title: Garlic (Allium sativum L.): a potential...
# 2143  title: Character association and path analysis...
# 2144  title: Antibacterial effect of different conce...
#
# [1956 rows x 9 columns]

# %%
gemini_key = <GEMINI_API_KEYS>
embeder = SentenceTransformer('all-MiniLM-L6-v2', device='cpu')
reducer = UMAP(n_components=2, n_neighbors=60, min_dist=0.2)

# cv = CountVectorizer(token_pattern=None, 
#     tokenizer=lambda text: word_tokenize(text, engine='attacut'), 
#     stop_words=list(thai_stopwords()))

cv = CountVectorizer(stop_words="english", ngram_range=(1, 1))
clustering = MeanShift(bandwidth=0.7)

tp_model = TopicModel(save_folder='output_test/', 
    # gpt_api_key=api_key,
    n_sample_summary=20,
    gemini_api_key=gemini_key,
    embedding=embeder, 
    reducer=reducer, 
    clustering=clustering, 
    countvector=cv, 
    batch_size=126, 
    device='cpu',
    verbose=True)

tp_model.params_llm_set(model_name='gemini-pro')

# %%
docs = df.text.tolist()

# %%
d_rs = tp_model.fit_transforms(docs)
# Out:
# embedding -> reduction dimension ...
# Batches:   0%|          | 0/16 [00:00<?, ?it/s]
# KeyboardInterrupt

# %%
df = d_rs.get('data')
df
# Out:
#                                            data_process  \
# 0     title: Quantitative HPLC Determination and Sta...
# 1     title: Insecticidal activity of Stemona collin...
# 2     title: Oral toxicity of various Stemona collin...
# 3     title: Optimized extraction for high yield of ...
# 4     title: Acetylcholinesterase inhibitory activit...
# ...                                                 ...
# 1951  title: Effects of Onion (Allium cepa L.) and G...
# 1952  title: Methods of Isolation of Active Substanc...
# 1953  title: Garlic (Allium sativum L.): a potential...
# 1954  title: Character association and path analysis...
# 1955  title: Antibacterial effect of different conce...
#
#                                                  vector         x         y  \
# 0     [-0.0074133547, -0.017918514, -0.08736931, -0.... -0.689890  9.657157
# 1     [0.0048623416, -0.044462435, -0.1135353, -0.04... -0.530240  9.409310
# 2     [0.053052347, -0.042213105, -0.082500555, -0.0... -0.421077  9.277965
# 3     [0.00866904, 0.013025655, -0.08530998, -0.0659... -0.650345  9.558570
# 4     [0.01852814, -0.03028386, -0.07568237, -0.0225... -0.746161  9.598317
# ...                                                 ...       ...       ...
# 1951  [-0.03210118, -0.026279455, -0.050988115, 0.03...  4.074474  4.481885
# 1952  [-0.04116749, -0.033044282, -0.09556768, 0.057...  4.163965  4.169012
# 1953  [-0.061984845, 0.005201916, -0.10571754, 0.041...  4.123065  3.772407
# 1954  [0.002141517, -0.003871272, -0.04897455, 0.057...  5.551926  3.876386
# 1955  [-0.028550493, -0.07910663, -0.06341982, -0.00...  3.375774  4.477656
#
#                                            data_display  cluster
# 0     X: -0.6899 Y: 9.6572 Content: title: Quantitat...        5
# 1     X: -0.5302 Y: 9.4093 Content: title: Insectici...        5
# 2     X: -0.4211 Y: 9.278 Content: title: Oral toxic...        5
# 3     X: -0.6503 Y: 9.5586 Content: title: Optimized...        5
# 4     X: -0.7462 Y: 9.5983 Content: title: Acetylcho...        5
# ...                                                 ...      ...
# 1951  X: 4.0745 Y: 4.4819 Content: title: Effects of...        2
# 1952  X: 4.164 Y: 4.169 Content: title: Methods of I...        2
# 1953  X: 4.1231 Y: 3.7724 Content: title: Garlic (Al...        2
# 1954  X: 5.5519 Y: 3.8764 Content: title: Character ...       17
# 1955  X: 3.3758 Y: 4.4777 Content: title: Antibacter...        2
#
# [1956 rows x 6 columns]

# %%
tw = d_rs.get('topword')
# tw['summary'] = tw['summary'].apply(eval)
tw
# Out:
#     cluster                                            topword  \
# 0         5  [[(compounds, 0.1477), (stemona, 0.1491), (ven...
# 1        16  [[(kaempferia, 0.1176), (diversity, 0.1281), (...
# 2         8  [[(title, 0.1449), (pub_year, 0.1449), (parvif...
# 3        14  [[(anti, 0.1442), (abstract, 0.1467), (activit...
# 4        13  [[(compounds, 0.1658), (pub_year, 0.1715), (ti...
# 5        15  [[(zingiber, 0.1344), (pub_year, 0.1344), (key...
# 6        18  [[(alzheimer, 0.1646), (inhibitory, 0.1646), (...
# 7        12  [[(keyword, 0.1582), (title, 0.1582), (abstrac...
# 8         1  [[(pub_year, 0.1549), (keyword, 0.1556), (frui...
# 9        19  [[(title, 0.1451), (abstract, 0.1451), (diabet...
# 10        0  [[(activity, 0.137), (curcuma_longa, 0.1435), ...
# 11        2  [[(allium_sativum, 0.1197), (pub_year, 0.1218)...
# 12       10  [[(title, 0.1224), (abstract, 0.128), (volatil...
# 13        4  [[(keyword, 0.1485), (pub_year, 0.1485), (abst...
# 14        3  [[(keyword, 0.1333), (abstract, 0.1355), (anti...
# 15        6  [[(title, 0.1214), (cell, 0.2018), (anti, 0.17...
# 16        7  [[(mg, 0.1282), (male, 0.1297), (effects, 0.13...
# 17       11  [[(activity, 0.1427), (keyword, 0.1479), (atra...
# 18        9  [[(accumulation, 0.1111), (volatile, 0.1141), ...
# 19       17  [[(keyword, 0.1316), (yield, 0.1716), (abstrac...
#
#                                               summary
# 0   {  "header": "Characterisation of alkaloids fr...
# 1                   {'header': None, 'summary': None}
# 2   {  "header": "Study of Phyto-Constituents and ...
# 3   { 'header': 'Phytochemical Classes and Ayurved...
# 4   { 'header': 'Lysiphyllum strychnifolium (Craib...
# 5   {  "header": "Repellency and Contact Toxicity ...
# 6   {  "header": "Alkaloids as Potential Inhibitor...
# 7   { "header": "Establishment of a Rapid Micropro...
# 8   { "header": "Potential of α-Mangostin from Gar...
# 9   {"header": "Prevention of Ischemic Heart Injur...
# 10  {'header': 'Antiviral effect of Curcuma longa ...
# 11  {  "header": "Garlic [Allium sativum]: A Revie...
# 12  {  "header": "Assessment of cropping patterns ...
# 13  { "header": "Zingiber cassumunar Roxb. (Plai):...
# 14  {'header': 'Kaempferia galanga L.: Progresses ...
# 15  { "header": "Identification and Evaluation of ...
# 16  {  "header": "Kaempferia parviflora: A Medicin...
# 17  {  "header": "Identification and Simultaneous ...
# 18  {  "header": "The Medicinal Properties of the ...
# 19  { 'header': 'Male Gametogenesis and Sterility ...

# %%
eval(tw.iloc[14]['summary'])
# Out:
# {'header': 'Kaempferia galanga L.: Progresses in Phytochemistry, Pharmacology, Toxicology and Ethnomedicinal Uses',
#  'summary': 'Kaempferia galanga L. is a traditional Chinese herb medicine that has been used to treat a variety of conditions, including cold, dry cough, toothaches, rheumatism, and hypertension. It is also used as a spice due to its highly aromatic nature. Ninety-seven compounds have been identified from the rhizome of K. galanga, including terpenoids, phenolics, cyclic dipeptides, flavonoids, diarylheptanoids, fatty acids, and esters. Modern pharmacology studies have revealed that extracts or secondary metabolites of the herb possess anti-inflammatory, anti-oxidant, anti-tumorous, anti-bacterial, and anti-angiogenesis effects. More in-depth studies are still necessary to systemically evaluate phytochemistry, pharmacological activities, toxicity, and quality control of this herb.'}

# %%
def print_topword(tw, cluster):
    max_ = 0
    tw = tw[tw['cluster'] == cluster]
    data = tw['topword'].values[0]
    data = dict(data[0])
    sorted_word_scores = dict(sorted(data.items(), key=lambda x: x[1], reverse=True))
    
    # หาความยาวของคำที่ยาวที่สุด
    for i in sorted_word_scores:
        if len(i) > max_:
            max_ = len(i)
    
    # พิมพ์คำและคะแนนพร้อมเส้นขีดล่าง (_)
    for word, score in sorted_word_scores.items():
        thresh = max_ - len(word)
        print(f'word: {word} {"_" * (thresh + 5)} scores: {score}')

# %%
for i in sorted(tw['cluster'].unique().tolist()) : 
    print()
    print(f'cluster: {i}')
    try : 
        print(f'header of cluster : {tw[tw['cluster']==i]['summary'].values[0].get('header')}')
        print(f'summary : {tw[tw['cluster']==i]['summary'].values[0].get('summary')}')

    except :
        pass
    print_topword(tw, i)
# Out:
# cluster: 0
# word: longa _____________ scores: 0.4312
# word: curcuma ___________ scores: 0.3744
# word: turmeric __________ scores: 0.3439
# word: curcumin __________ scores: 0.2656
# word: title _____________ scores: 0.1507
# word: abstract __________ scores: 0.1507
# word: keyword ___________ scores: 0.1501
# word: pub_year __________ scores: 0.1501
# word: curcuma_longa _____ scores: 0.1435
# word: activity __________ scores: 0.137
#
# cluster: 1
# word: mangostana _____ scores: 0.36
# word: mangosteen _____ scores: 0.3544
# word: garcinia _______ scores: 0.316
# word: mangostin ______ scores: 0.217
# word: extract ________ scores: 0.1891
# word: activity _______ scores: 0.1877
# word: fruit __________ scores: 0.157
# word: abstract _______ scores: 0.157
# word: keyword ________ scores: 0.1556
# word: pub_year _______ scores: 0.1549
#
# cluster: 2
# word: garlic _____________ scores: 0.7169
# word: allium _____________ scores: 0.2629
# word: sativum ____________ scores: 0.2373
# word: activity ___________ scores: 0.1508
# word: extract ____________ scores: 0.1259
# word: abstract ___________ scores: 0.1225
# word: pub_year ___________ scores: 0.1218
# word: keyword ____________ scores: 0.1218
# word: title ______________ scores: 0.1218
# word: allium_sativum _____ scores: 0.1197
#
# cluster: 3
# word: galanga ________ scores: 0.4653
# word: kaempferia _____ scores: 0.3154
# word: extract ________ scores: 0.2221
# word: activity _______ scores: 0.1999
# word: ethyl __________ scores: 0.1777
# word: anti ___________ scores: 0.1732
# word: rhizome ________ scores: 0.1599
# word: abstract _______ scores: 0.1355
# word: keyword ________ scores: 0.1333
# word: pub_year _______ scores: 0.1333
#
# cluster: 4
# word: cassumunar _____ scores: 0.4264
# word: zingiber _______ scores: 0.35
# word: extract ________ scores: 0.2079
# word: activity _______ scores: 0.1877
# word: roxb ___________ scores: 0.1782
# word: compound _______ scores: 0.1644
# word: abstract _______ scores: 0.1496
# word: title __________ scores: 0.1496
# word: keyword ________ scores: 0.1485
# word: pub_year _______ scores: 0.1485
#
# cluster: 5
# word: alkaloids _____ scores: 0.3596
# word: activity ______ scores: 0.269
# word: extract _______ scores: 0.1965
# word: abstract ______ scores: 0.184
# word: title _________ scores: 0.1798
# word: keyword _______ scores: 0.1798
# word: pub_year ______ scores: 0.1784
# word: venosa ________ scores: 0.1742
# word: stemona _______ scores: 0.1491
# word: compounds _____ scores: 0.1477
#
# cluster: 6
# word: parviflora _____ scores: 0.3673
# word: kp _____________ scores: 0.3217
# word: kaempferia _____ scores: 0.2944
# word: extract ________ scores: 0.2732
# word: activity _______ scores: 0.2079
# word: cell ___________ scores: 0.2018
# word: cells __________ scores: 0.1791
# word: anti ___________ scores: 0.17
# word: abstract _______ scores: 0.1244
# word: title __________ scores: 0.1214
#
# cluster: 7
# word: parviflora _____ scores: 0.3819
# word: kp _____________ scores: 0.2917
# word: extract ________ scores: 0.2861
# word: kaempferia _____ scores: 0.2551
# word: study __________ scores: 0.1903
# word: kpe ____________ scores: 0.1635
# word: rats ___________ scores: 0.1621
# word: effects ________ scores: 0.1339
# word: male ___________ scores: 0.1297
# word: mg _____________ scores: 0.1282
#
# cluster: 8
# word: parviflora ______ scores: 0.3002
# word: extract _________ scores: 0.2795
# word: kaempferia ______ scores: 0.2671
# word: antioxidant _____ scores: 0.2339
# word: activity ________ scores: 0.207
# word: abstract ________ scores: 0.1553
# word: compounds _______ scores: 0.1553
# word: title ___________ scores: 0.1449
# word: pub_year ________ scores: 0.1449
# word: using ___________ scores: 0.1449
#
# cluster: 9
# word: lancea ___________ scores: 0.6049
# word: atractylodes _____ scores: 0.2116
# word: soil _____________ scores: 0.1801
# word: endophytic _______ scores: 0.1696
# word: plant ____________ scores: 0.1576
# word: growth ___________ scores: 0.1561
# word: oil ______________ scores: 0.1201
# word: volatile _________ scores: 0.1141
# word: stress ___________ scores: 0.1126
# word: accumulation _____ scores: 0.1111
#
# cluster: 10
# word: lancea ___________ scores: 0.4707
# word: atractylodes _____ scores: 0.4406
# word: analysis _________ scores: 0.1902
# word: rhizome __________ scores: 0.1393
# word: essential ________ scores: 0.1318
# word: species __________ scores: 0.1318
# word: abstract _________ scores: 0.128
# word: chinensis ________ scores: 0.1261
# word: volatile _________ scores: 0.1243
# word: title ____________ scores: 0.1224
#
# cluster: 11
# word: lancea __________________ scores: 0.3577
# word: atractylodes ____________ scores: 0.3164
# word: al ______________________ scores: 0.2665
# word: compounds _______________ scores: 0.1582
# word: abstract ________________ scores: 0.153
# word: keyword _________________ scores: 0.1479
# word: title ___________________ scores: 0.1479
# word: pub_year ________________ scores: 0.1479
# word: atractylodes_lancea _____ scores: 0.1444
# word: activity ________________ scores: 0.1427
#
# cluster: 12
# word: galanga ________ scores: 0.2489
# word: kaempferia _____ scores: 0.2412
# word: rhizome ________ scores: 0.2045
# word: medium _________ scores: 0.1968
# word: mg _____________ scores: 0.1852
# word: vitro __________ scores: 0.1852
# word: plant __________ scores: 0.1717
# word: abstract _______ scores: 0.1621
# word: keyword ________ scores: 0.1582
# word: title __________ scores: 0.1582
#
# cluster: 13
# word: plants _________ scores: 0.2344
# word: used ___________ scores: 0.2087
# word: extraction _____ scores: 0.2001
# word: abstract _______ scores: 0.1915
# word: extracts _______ scores: 0.1915
# word: herbal _________ scores: 0.1772
# word: pub_year _______ scores: 0.1715
# word: title __________ scores: 0.1715
# word: keyword ________ scores: 0.1715
# word: compounds ______ scores: 0.1658
#
# cluster: 14
# word: cancer ________ scores: 0.2884
# word: cells _________ scores: 0.2346
# word: extract _______ scores: 0.2322
# word: cell __________ scores: 0.1955
# word: compounds _____ scores: 0.1907
# word: plants ________ scores: 0.1882
# word: plant _________ scores: 0.1858
# word: activity ______ scores: 0.1833
# word: abstract ______ scores: 0.1467
# word: anti __________ scores: 0.1442
#
# cluster: 15
# word: oil ____________ scores: 0.4625
# word: essential ______ scores: 0.3917
# word: activity _______ scores: 0.2501
# word: oils ___________ scores: 0.2052
# word: galanga ________ scores: 0.1706
# word: cassumunar _____ scores: 0.1518
# word: abstract _______ scores: 0.1373
# word: zingiber _______ scores: 0.1344
# word: pub_year _______ scores: 0.1344
# word: keyword ________ scores: 0.1344
#
# cluster: 16
# word: species ________ scores: 0.5515
# word: plants _________ scores: 0.2039
# word: abstract _______ scores: 0.1542
# word: plant __________ scores: 0.1516
# word: pub_year _______ scores: 0.1516
# word: keyword ________ scores: 0.1516
# word: title __________ scores: 0.1516
# word: medicinal ______ scores: 0.1359
# word: diversity ______ scores: 0.1281
# word: kaempferia _____ scores: 0.1176
#
# cluster: 17
# word: garlic _____________ scores: 0.5691
# word: allium _____________ scores: 0.2774
# word: bulb _______________ scores: 0.246
# word: sativum ____________ scores: 0.2402
# word: yield ______________ scores: 0.1716
# word: genetic ____________ scores: 0.1459
# word: abstract ___________ scores: 0.1344
# word: keyword ____________ scores: 0.1316
# word: title ______________ scores: 0.1316
# word: allium_sativum _____ scores: 0.1316
#
# cluster: 18
# word: ache _____________________ scores: 0.2704
# word: alkaloids ________________ scores: 0.2547
# word: inhibitors _______________ scores: 0.2155
# word: activity _________________ scores: 0.2116
# word: disease __________________ scores: 0.2077
# word: ad _______________________ scores: 0.2038
# word: treatment ________________ scores: 0.1724
# word: acetylcholinesterase _____ scores: 0.1685
# word: alzheimer ________________ scores: 0.1646
# word: inhibitory _______________ scores: 0.1646
#
# cluster: 19
# word: compounds _____ scores: 0.2446
# word: diabetic ______ scores: 0.228
# word: glucose _______ scores: 0.1907
# word: using _________ scores: 0.1741
# word: activity ______ scores: 0.1617
# word: extract _______ scores: 0.1575
# word: study _________ scores: 0.1575
# word: title _________ scores: 0.1451
# word: abstract ______ scores: 0.1451
# word: pub_year ______ scores: 0.1451

# %%
wizmap_local(directory_folder_of_wizmap='output_test/wizmapJson/')
# Out:
# https://poloclub.github.io/wizmap/?dataURL=http://localhost:8000/output_test/wizmapJson/data.ndjson&gridURL=http://localhost:8000/output_test/wizmapJson/grid.json
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 127.0.0.1 - - [25/Jun/2024 14:58:58] "OPTIONS /output_test/wizmapJson/grid.json HTTP/1.1" 204 -
# 127.0.0.1 - - [25/Jun/2024 14:58:58] "OPTIONS /output_test/wizmapJson/data.ndjson HTTP/1.1" 204 -
# <class 'http_server.server.CORSRequestHandler'>
# Starting httpd server on port 8000...
# Traceback (most recent call last):
#   File "/Users/peetiphartsuebpeng/Documents/CONDA_ENV/env-wizmap/bin/server", line 8, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/Users/peetiphartsuebpeng/Documents/CONDA_ENV/env-wizmap/lib/python3.12/site-packages/http_server/server.py", line 31, in main
#     run(port=args.port, allow_all_cors=args.allow_cors)
#   File "/Users/peetiphartsuebpeng/Documents/CONDA_ENV/env-wizmap/lib/python3.12/site-packages/http_server/server.py", line 22, in run
#     httpd.serve_forever()
#   File "/Users/peetiphartsuebpeng/Documents/CONDA_ENV/env-wizmap/lib/python3.12/socketserver.py", line 235, in serve_forever
#     ready = selector.select(poll_interval)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/peetiphartsuebpeng/Documents/CONDA_ENV/env-wizmap/lib/python3.12/selectors.py", line 415, in select
#     fd_event_list = self._selector.poll(timeout)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# KeyboardInterrupt
